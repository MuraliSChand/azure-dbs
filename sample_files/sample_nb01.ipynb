# %% [markdown]
# ## A sample notebook for adf testing

# %%
print(spark)

# %%
dbutils.widgets.text("Name","value")
name = dbutils.widgets.get("Name")

# %%
print(name)

# %%
import json
j = json.dumps({name : name + str(spark)})

# %%
dbutils.notebook.exit(j)
