# %%
df = spark.read.option("header","true").csv("abfss://dbs-uc-data01@aztrainsav01.dfs.core.windows.net/landing-data/git/titanic.csv.zip/titanic.csv")

# %%
df.limit(1).show()

# %%
df.explain(True)

# %%
# %sql
select current_database();

# %%
# %sql
create or replace table titanic as select * from csv.`abfss://dbs-uc-data01@aztrainsav01.dfs.core.windows.net/landing-data/git/titanic.csv.zip/titanic.csv` WITH (header = "true");

# %%
# %sql
select * from titanic limit 5;

# %%
# %sql
create or replace table titanic_ext
location "abfss://dbs-uc-data01@aztrainsav01.dfs.core.windows.net/tables/" 
as 
select * from csv.`abfss://dbs-uc-data01@aztrainsav01.dfs.core.windows.net/landing-data/git/titanic.csv.zip/titanic.csv` with(header = "true")

# %%
# %sql
create table titanic_no_delta
using csv
location "abfss://dbs-uc-data01@aztrainsav01.dfs.core.windows.net/landing-data/git/titanic.csv.zip/titanic.csv"
options(
  header = "true"
)

# %%
import json
rows = spark.table("titanic").count()
dbutils.notebook.exit(json.dumps({"rows": rows}))

# %%
password = dbutils.secrets.get("azure-secrets","sqldb_pwd")
dbname = dbutils.secrets.get("azure-secrets","dbname")
print(password)

# %%
df = spark.read.option("header","true").csv("abfss://dbs-uc-data01@aztrainsav01.dfs.core.windows.net/landing-data/git/titanic.csv.zip/titanic.csv")
df.limit(5).show()

# %%
df.write.format("jdbc").option("url",f"jdbc:sqlserver://az-train-sqlser01.database.windows.net:1433;database={dbname};").option("dbtable","titanic").option("user","admin01").option("password",password).mode("overwrite").save()

# %%
df = spark.read.format("jdbc").option("url",f"jdbc:sqlserver://az-train-sqlser01.database.windows.net:1433;database={dbname};").option("dbtable","titanic").option("user","admin01").option("password",password).load()
df.limit(5).show()
